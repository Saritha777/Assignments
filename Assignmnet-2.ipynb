# %%
#1. Importing data from csv file
import pandas as pd
import numpy as np
df=pd.read_csv("Desktop\\python programs\\Customers.csv")
df
# Out:
#       Customer_ID Gender  First_Date First_region     First_state  \
# 0       129609144      M    20130130         West         Gujarat
# 1       129627580      M    20130129        North           Delhi
# 2       130363481      M    20130221         West         Gujarat
# 3        49817480      M    20130222         West     Maharashtra
# 4       126343829      F    20130301        North           Delhi
# 5         8223758      F    20130314         West         Gujarat
# 6       131816709      M    20130318        South  Andhra Pradesh
# 7       118543320      F    20130321        North   Uttar Pradesh
# 8       131365512      M    20130323         East     West Bengal
# 9          758571      M    20130324        South       Karnataka
# 10       85489184      M    20120101         West     Maharashtra
# 11       85438231      M    20120103         West     Maharashtra
# 12       74053888      F    20120102         West         Gujarat
# ...

# %%
#2. functions in package

print(df.shape)
print(df.index)
print(df.dtypes.ndim)
print(df.get_dtype_counts)
print(df.columns)
print(df.info)
# Out:
# (10000, 14)
# RangeIndex(start=0, stop=10000, step=1)
# 1
# <bound method NDFrame.get_dtype_counts of       Customer_ID Gender  First_Date First_region     First_state  \
# 0       129609144      M    20130130         West         Gujarat
# 1       129627580      M    20130129        North           Delhi
# 2       130363481      M    20130221         West         Gujarat
# 3        49817480      M    20130222         West     Maharashtra
# 4       126343829      F    20130301        North           Delhi
# 5         8223758      F    20130314         West         Gujarat
# 6       131816709      M    20130318        South  Andhra Pradesh
# 7       118543320      F    20130321        North   Uttar Pradesh
# 8       131365512      M    20130323         East     West Bengal
# 9          758571      M    20130324        South       Karnataka
# 10       85489184      M    20120101         West     Maharashtra
# 11       85438231      M    20120103         West     Maharashtra
# ...

# %%
#3. percentage of missing customer values 
percentage=df.Customer_Value.isnull().sum()*100/len(df)
percentage
# Out:
# 0.36

# %%
#4.unique and duplicates
import pandas as pd
import numpy as np
df=pd.read_csv("Desktop\\python programs\\Customers.csv")
Duplicate=df[df["Customer_ID"].duplicated()]
Unique_Values=df[df["Customer_ID"].duplicated()==False]
print(Duplicate)
print(Unique_Values)
# Out:
#       Customer_ID   Gender  First_Date First_region     First_state  \
# 9817    113918804        M    20120226         West         Gujarat
# 9818    113933467        F    20120226        South      Tamil Nadu
# 9819     41337621        F    20120228         West         Gujarat
# 9820      6896372        M    20120228         West     Maharashtra
# 9821    114142599        M    20120303         West         Gujarat
# 9822       586957        M    20120308        North   Uttar Pradesh
# 9823    114330400        M    20120307         West         Gujarat
# 9824    114731117  unknown    20120314         West         Gujarat
# 9825    114908563        F    20120318         West         Gujarat
# 9826       823086        M    20120316         West     Maharashtra
# 9827    114940492        F    20120317        North   Uttar Pradesh
# 9828     12605170        M    20120330        North   Uttar Pradesh
# 9829     50248089        F    20120330        South      Tamil Nadu
# ...

# %%
#5.Customer value greater than 10000
df[df["Customer_Value"]>10000]
# Out:
#       Customer_ID Gender  First_Date First_region     First_state  \
# 14        1610085      F    20120103        North           Delhi
# 15        7518872      M    20120104        North   Uttar Pradesh
# 18       63508964      M    20120106         West     Maharashtra
# 19       23667984      F    20120107         West     Maharashtra
# 20       84634600      M    20120108        South       Karnataka
# 21       85207999      M    20120110        South  Andhra Pradesh
# 24       87030390      M    20120111         East     West Bengal
# 26       12935950      M    20120113         West         Gujarat
# 27       10954886      F    20120115        North  Madhya Pradesh
# 29        7514232      M    20120114        North           Delhi
# 30         328670      M    20120115        North           Delhi
# 31         237645      M    20120117        North  Madhya Pradesh
# 32       36292837      M    20120118         West         Gujarat
# ...

# %%
#6.Adding customer value segments
df["Customer_value_segments"]=["High Value Segment" if i>25000 else "Low Value Segment" if i<=10000 else "Medium Value Segment" for i in df["Customer_Value"]]   
df
# Out:
#       Customer_ID Gender  First_Date First_region     First_state  \
# 0       129609144      M    20130130         West         Gujarat
# 1       129627580      M    20130129        North           Delhi
# 2       130363481      M    20130221         West         Gujarat
# 3        49817480      M    20130222         West     Maharashtra
# 4       126343829      F    20130301        North           Delhi
# 5         8223758      F    20130314         West         Gujarat
# 6       131816709      M    20130318        South  Andhra Pradesh
# 7       118543320      F    20130321        North   Uttar Pradesh
# 8       131365512      M    20130323         East     West Bengal
# 9          758571      M    20130324        South       Karnataka
# 10       85489184      M    20120101         West     Maharashtra
# 11       85438231      M    20120103         West     Maharashtra
# 12       74053888      F    20120102         West         Gujarat
# ...

# %%
#7. creating variables average revenue and balance points
import pandas as pd
df=pd.read_csv("Desktop\\python programs\\Customers.csv")
df=df.assign(Average_Revenue_Per_Trip=df["Customer_Value"]/df["Buy_Times"],
                Balance_Points=df["Points_Earned"]-df["Points_Redeemed"])
df
# Out:
#       Customer_ID Gender  First_Date First_region     First_state  \
# 0       129609144      M    20130130         West         Gujarat
# 1       129627580      M    20130129        North           Delhi
# 2       130363481      M    20130221         West         Gujarat
# 3        49817480      M    20130222         West     Maharashtra
# 4       126343829      F    20130301        North           Delhi
# 5         8223758      F    20130314         West         Gujarat
# 6       131816709      M    20130318        South  Andhra Pradesh
# 7       118543320      F    20130321        North   Uttar Pradesh
# 8       131365512      M    20130323         East     West Bengal
# 9          758571      M    20130324        South       Karnataka
# 10       85489184      M    20120101         West     Maharashtra
# 11       85438231      M    20120103         West     Maharashtra
# 12       74053888      F    20120102         West         Gujarat
# ...

# %%
#8. no. of days between last day and today
import pandas as pd
import datetime as dt
data=pd.read_csv("Desktop\\python programs\\Customers.csv")
today=pd.to_datetime(dt.datetime.now().date())
Days=today-pd.to_datetime(data["Recent_Date"],format='%Y%m%d')
Days
# Out:
# 0      2372 days
# 1      2390 days
# 2      2367 days
# 3      2366 days
# 4      2359 days
# 5      2346 days
# 6      2342 days
# 7      2339 days
# 8      2329 days
# 9      2335 days
# 10     2784 days
# 11     2469 days
# 12     2346 days
# 13     2454 days
# 14     2498 days
# 15     2396 days
# 16     2782 days
# 17     2376 days
# 18     2366 days
# 19     2347 days
# 20     2353 days
# 21     2421 days
# 22     2774 days
# 23     2440 days
# 24     2358 days
# 25     2774 days
# 26     2610 days
# 27     2401 days
# 28     2366 days
# 29     2411 days
#           ...
# 9970   2330 days
# 9971   2366 days
# 9972   2497 days
# 9973   2366 days
# 9974   2341 days
# 9975   2640 days
# 9976   2405 days
# 9977   2764 days
# 9978   2758 days
# 9979   2453 days
# 9980   2348 days
# 9981   2754 days
# 9982   2347 days
# 9983   2350 days
# 9984   2350 days
# 9985   2439 days
# 9986   2753 days
# 9987   2332 days
# 9988   2753 days
# 9989   2753 days
# 9990   2751 days
# ...

# %%
#9.percentage of sales by last city,region and state
import pandas as pd
data=pd.read_csv("Desktop\\python programs\\Customers.csv")
D1=data[["Last_region","Last_state","Last_city","Customer_Value"]]
D1.groupby(["Last_region","Last_state","Last_city"])["Customer_Value"].sum()/D1.Customer_Value.sum()*100
# Out:
# Last_region  Last_state         Last_city
# East         Assam              Guwahati             1.557344
#              Bihar              Begusarai            0.020559
#                                 Bhagalpur            0.002230
#                                 Katihar              0.046883
#                                 Patna                0.185101
#                                 Purnia               0.005867
#              Jharkhand          Dhanbad              0.197452
#                                 Jamshedpur           0.002848
#                                 Ranchi               0.045349
#              Tripura            Agartala             0.018824
#              West Bengal        Asansol              0.003035
#                                 Baranagar            0.015954
#                                 Barasat              0.004028
#                                 Bhatpara             0.063541
# ...

# %%
#10.count of customers,average transactions and purchases
import pandas as pd

#count of customers
print(df.groupby(["Last_state","Last_city"])["Customer_ID"].count())
#average purchases
print(df.groupby(["Last_state","Last_city"])["Buy_Times"].sum()/df.groupby(["Last_state","Last_city"])["Buy_Times"].count())
#average transactions
print(df.groupby(["Last_state","Last_city"])["Average_Revenue_Per_Trip"].mean())
# Out:
# Last_state         Last_city
# Andhra Pradesh     Guntur                1
#                    Kurnool               1
#                    Tirupati              2
#                    Vijayawada           20
#                    Visakhapatnam       117
#                    Vizianagaram          1
# Assam              Guwahati             30
# Bihar              Begusarai             1
#                    Bhagalpur             1
#                    Katihar               2
#                    Patna                20
#                    Purnia                1
# Chandigarh         Chandigarh            6
# Chhattisgarh       Korba                 1
#                    Raipur                1
# Delhi              Delhi              1034
#                    Karawal Nagar         2
#                    New Delhi             1
# Gujarat            Ahmedabad           621
#                    Gandhidham            1
#                    Jamnagar              6
# ...
